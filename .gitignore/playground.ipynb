# %%
import pandas as pd
from sqlalchemy import create_engine,text

# %%
pip install sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
DATABASE_URL="mysql+pymysql://root:Pikachu@123@localhost:3306/sql_db"

# %%
from sqlalchemy import create_engine,text

engine=create_engine(DATABASE_URL,echo=False)

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM products"))
    rows = result.fetchall()
# Out:
# 2025-12-18 12:51:42,009 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-18 12:51:42,010 INFO sqlalchemy.engine.Engine SELECT * FROM products
# 2025-12-18 12:51:42,010 INFO sqlalchemy.engine.Engine [generated in 0.00137s] {}
# 2025-12-18 12:51:42,042 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
from sqlalchemy import create_engine, text
from urllib.parse import quote_plus

password = quote_plus("Pikachu@123")

engine = create_engine(
    f"mysql+pymysql://root:{password}@localhost:3306/sql_db",
    echo=True
)

with engine.connect() as conn:
    conn.execute(text("SELECT 1"))
    print("✅ Connected successfully")
# Out:
# 2025-12-18 12:51:28,403 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-12-18 12:51:28,405 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-18 12:51:28,415 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-12-18 12:51:28,416 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-18 12:51:28,418 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-12-18 12:51:28,419 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-18 12:51:28,428 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-18 12:51:28,431 INFO sqlalchemy.engine.Engine SELECT 1
# 2025-12-18 12:51:28,432 INFO sqlalchemy.engine.Engine [generated in 0.00414s] {}
# ✅ Connected successfully
# 2025-12-18 12:51:28,433 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
def get_users():
    with engine.connect() as conn:
        result = conn.execute(text("SELECT * FROM products"))
        return [dict(row._mapping) for row in result.fetchall()]

# %%
get_users()
# Out:
# 2025-12-18 12:53:57,304 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-18 12:53:57,305 INFO sqlalchemy.engine.Engine SELECT * FROM products
# 2025-12-18 12:53:57,306 INFO sqlalchemy.engine.Engine [cached since 135.3s ago] {}
# 2025-12-18 12:53:57,311 INFO sqlalchemy.engine.Engine ROLLBACK
# [{'product_id': 1,
#   'product_name': 'Just Device',
#   'category': 'Groceries',
#   'price': 143.97,
#   'stock_quantity': 847,
#   'reorder_level': 114,
#   'supplier_id': 19},
#  {'product_id': 2,
#   'product_name': 'And Table',
#   'category': 'Groceries',
#   'price': 150.84,
#   'stock_quantity': 100,
#   'reorder_level': 99,
#   'supplier_id': 42},
#  {'product_id': 3,
#   'product_name': 'Six Table',
#   'category': 'Clothing',
#   'price': 115.05,
#   'stock_quantity': 442,
#   'reorder_level': 76,
#   'supplier_id': 23},
#  {'product_id': 4,
#   'product_name': 'Tax Device',
#   'category': 'Groceries',
#   'price': 121.81,
#   'stock_quantity': 644,
# ...

# %%
import streamlit as st
st.dataframe(get_users())
# Out:
# 2025-12-18 12:55:38,547 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-18 12:55:38,549 INFO sqlalchemy.engine.Engine SELECT * FROM products
# 2025-12-18 12:55:38,551 INFO sqlalchemy.engine.Engine [cached since 236.5s ago] {}
# 2025-12-18 12:55:38,554 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-12-18 12:55:38.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 12:55:38.837
# ...
#   command:
#
#     streamlit run C:\Users\khanz\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-12-18 12:55:38.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-18 12:55:38.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
df1=pd.read_sql("Select * from products",engine)
st.dataframe(df1)
# Out:
# 2025-12-18 13:25:58,355 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-18 13:25:58,356 INFO sqlalchemy.engine.Engine DESCRIBE `sql_db`.`Select * from products`
# 2025-12-18 13:25:58,358 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-18 13:25:58,362 INFO sqlalchemy.engine.Engine Select * from products
# 2025-12-18 13:25:58,364 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-18 13:25:58,372 INFO sqlalchemy.engine.Engine ROLLBACK
#      product_id   product_name   category    price  stock_quantity  \
# 0             1    Just Device  Groceries   143.97             847
# 1             2      And Table  Groceries   150.84             100
# 2             3      Six Table   Clothing   115.05             442
# 3             4     Tax Device  Groceries   121.81             644
# 4             5  Foreign Table   Clothing   402.93             959
# ..          ...            ...        ...      ...             ...
# ...

# %%
query="SELECT * FROM products WHERE stock_quantity>%(quant)s"
df=pd.read_sql(query,engine,params={"quant":200})
# Out:
# 2025-12-18 13:34:55,657 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-18 13:34:55,658 INFO sqlalchemy.engine.Engine DESCRIBE `sql_db`.`SELECT * FROM products WHERE stock_quantity>%%(quant)s`
# 2025-12-18 13:34:55,659 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-18 13:34:55,661 INFO sqlalchemy.engine.Engine SELECT * FROM products WHERE stock_quantity>%(quant)s
# 2025-12-18 13:34:55,663 INFO sqlalchemy.engine.Engine [raw sql] {'quant': 200}
# 2025-12-18 13:34:55,671 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
df.head()
# Out:
#    product_id    product_name   category   price  stock_quantity  \
# 0           1     Just Device  Groceries  143.97             847
# 1           3       Six Table   Clothing  115.05             442
# 2           4      Tax Device  Groceries  121.81             644
# 3           5   Foreign Table   Clothing  402.93             959
# 4           6  Personal Table       Toys   65.51             962
#
#    reorder_level  supplier_id
# 0            114           19
# 1             76           23
# 2             84           49
# 3             86            5
# 4             59           39
